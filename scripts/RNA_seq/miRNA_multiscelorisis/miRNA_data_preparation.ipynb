# %%
# importing python libraries 
import re
import pandas as pd
import numpy as np

# %%
#loading the miRNA dataset into jupyter
data = pd.read_csv('MiRNA_studies.csv',sep=",",header=None)

# %%
#determines the shape ofthe data
data.shape
# Out:
# (221, 2107)

# %%
#checking the number of data available in our data sets
print(data.dtypes)
# Out:
# 0       object
# 1       object
# 2       object
# 3       object
# 4       object
#          ...
# 2102    object
# 2103    object
# 2104    object
# 2105    object
# 2106    object
# Length: 2107, dtype: object

# %%
#creating dataframes
df=data[[0,1]]
print(df)
# Out:
#                                                      0              1
# 0                                               miRNA   Target Gene 1
# 1          hsa-miR-200b-3p/hsa-miR-200c-3p/hsa-miR-429           ZEB1
# 2                                       hsa-miR-182-5p          ROCK1
# 3                                     hsa-miR-101-3p.2        ZFP36L2
# 4    hsa-miR-130a-3p/hsa-miR-130b-3p/hsa-miR-301a-3...         ZBTB20
# ..                                                 ...            ...
# 216                                     hsa-miR-490-3p        HNRNPA1
# 217                       hsa-miR-151a-5p/hsa-miR-151b          N4BP1
# 218                       hsa-miR-551a/hsa-miR-551b-3p          MEF2C
# 219           hsa-miR-185-5p/hsa-miR-4306/hsa-miR-4644         CAMK1G
# 220                                    hsa-miR-193a-5p          SENP1
#
# [221 rows x 2 columns]

# %%
#creating the different dataframes to merge in one large dataframe
num = data[data.columns[0]].count()
# loops through the columns and creates dataframes as shown below
for i in range(1,num+1):
    globals()[f"df{i}"] = data[[0,i]] 
df2.head(50)
# Out:
#                                                     0              2
# 0                                              miRNA   Target Gene 2
# 1         hsa-miR-200b-3p/hsa-miR-200c-3p/hsa-miR-429           ZEB2
# 2                                      hsa-miR-182-5p           BNC2
# 3                                    hsa-miR-101-3p.2          PDE7A
# 4   hsa-miR-130a-3p/hsa-miR-130b-3p/hsa-miR-301a-3...         SKIDA1
# 5                                        hsa-miR-9-5p        ONECUT1
# 6                       hsa-miR-1271-5p/hsa-miR-96-5p           FRS2
# 7                                      hsa-miR-493-5p           PIGV
# 8                                     hsa-miR-499a-5p          PTAR1
# 9                     hsa-miR-208a-3p/hsa-miR-208b-3p          PTPN4
# 10     hsa-miR-128-3p/hsa-miR-216a-3p/hsa-miR-3681-3p          BAZ2B
# 11  hsa-miR-106a-5p/hsa-miR-106b-5p/hsa-miR-17-5p/...         MAP3K2
# 12                                     hsa-miR-340-5p          USP28
# 13                                   hsa-miR-142-3p.2          SH2B3
# 14                                     hsa-miR-144-3p           GRM5
# 15                      hsa-miR-27a-3p/hsa-miR-27b-3p         RSBN1L
# 16                     hsa-miR-145-5p/hsa-miR-5195-3p         LARP4B
# 17                                   hsa-miR-101-3p.1           GSE1
# 18                     hsa-miR-141-3p/hsa-miR-200a-3p          RNF11
# 19  hsa-miR-30a-5p/hsa-miR-30b-5p/hsa-miR-30c-5p/h...         CELSR3
# 20                                   hsa-miR-124-3p.1         ZBTB20
# 21  hsa-miR-181a-5p/hsa-miR-181b-5p/hsa-miR-181c-5...           FIGN
# 22                         hsa-miR-300/hsa-miR-381-3p          HOXC8
# 23                     hsa-miR-133a-3p.2/hsa-miR-133b           GDNF
# 24                                     hsa-miR-129-5p           NFIB
# 25                                   hsa-miR-140-3p.1          NR6A1
# 26  hsa-let-7a-5p/hsa-let-7b-5p/hsa-let-7c-5p/hsa-...         ACVR1B
# 27  hsa-miR-302a-3p/hsa-miR-302b-3p/hsa-miR-302c-3...         ZBTB7A
# 28                                   hsa-miR-183-5p.2          MAPK1
# 29                                    hsa-miR-323a-3p         AKAP11
# 30                                      hsa-miR-31-5p         HIF1AN
# 31                  hsa-miR-129-1-3p/hsa-miR-129-2-3p          TANC2
# 32               hsa-miR-1-3p/hsa-miR-206/hsa-miR-613           G6PD
# 33                        hsa-miR-3167/hsa-miR-876-5p          CDC27
# 34                                   hsa-miR-183-5p.1          PTPN4
# 35                    hsa-miR-135a-5p/hsa-miR-135b-5p           SYT2
# 36                    hsa-miR-124-3p.2/hsa-miR-506-3p          TEAD1
# 37  hsa-miR-34a-5p/hsa-miR-34c-5p/hsa-miR-449a/hsa...           HCN3
# 38                     hsa-miR-142-5p/hsa-miR-5590-3p            DMD
# 39                                        hsa-miR-802          BTBD7
# 40                                        hsa-miR-421         APPBP2
# 41                        hsa-miR-103a-3p/hsa-miR-107          SCN1A
# 42  hsa-miR-25-3p/hsa-miR-32-5p/hsa-miR-363-3p/hsa...          HIPK3
# 43                                     hsa-miR-582-5p           AQP2
# 44       hsa-miR-29a-3p/hsa-miR-29b-3p/hsa-miR-29c-3p           NAV1
# 45                        hsa-miR-495-3p/hsa-miR-5688         NIPAL3
# 46                                     hsa-miR-138-5p           BTG1
# 47                                     hsa-miR-299-5p         IL1RAP
# 48    hsa-miR-219a-5p/hsa-miR-4782-3p/hsa-miR-6766-3p          CLYBL
# 49                                        hsa-miR-137           MITF

# %%
#creating the different dataframes to merge in one large dataframe
num = data[data.columns[0]].count()
# loops through the columns and creates dataframes as shown below
for i in range(1,num):
    globals()[f"df{i}"].columns = ["miRNA", "Target"] 
df220.head()
# Out:
#                                                miRNA           Target
# 0                                             miRNA   Target Gene 220
# 1        hsa-miR-200b-3p/hsa-miR-200c-3p/hsa-miR-429           RBFOX3
# 2                                     hsa-miR-182-5p             FGD4
# 3                                   hsa-miR-101-3p.2            STAT6
# 4  hsa-miR-130a-3p/hsa-miR-130b-3p/hsa-miR-301a-3...             HHIP

# %%
#merging the different dataframes on one table 
for i in range(1,221):
    df1 = df1.append(globals()[f"df{i}"].iloc[1:221], 
                   ignore_index=True)

# %%
#determing the number of the miRNA  available
df1.shape
# Out:
# (48621, 2)

# %%
#removing the ones that were blank or represented by "Nan"
data_set=df1.dropna()

# %%
data_set.shape
# Out:
# (41987, 2)

# %%
# further cleaning the dataframe sets 
df_set2 = data_set[data_set['Target']!= data_set['Target'].str.extract(r'(Mar-[0-9]*)', expand=False).str.strip()]
df_set2.shape
# Out:
# (41920, 2)

# %%
# visualizing the data created  
df_set2.head(50)
# Out:
#                                                 miRNA         Target
# 0                                              miRNA   Target Gene 1
# 1         hsa-miR-200b-3p/hsa-miR-200c-3p/hsa-miR-429           ZEB1
# 2                                      hsa-miR-182-5p          ROCK1
# 3                                    hsa-miR-101-3p.2        ZFP36L2
# 4   hsa-miR-130a-3p/hsa-miR-130b-3p/hsa-miR-301a-3...         ZBTB20
# 5                                        hsa-miR-9-5p        ONECUT2
# 6                       hsa-miR-1271-5p/hsa-miR-96-5p          NOVA2
# 7                                      hsa-miR-493-5p           PDK4
# 8                                     hsa-miR-499a-5p            QKI
# 9                     hsa-miR-208a-3p/hsa-miR-208b-3p            QKI
# 10     hsa-miR-128-3p/hsa-miR-216a-3p/hsa-miR-3681-3p          SZRD1
# 11  hsa-miR-106a-5p/hsa-miR-106b-5p/hsa-miR-17-5p/...         BRMS1L
# 12                                     hsa-miR-340-5p        CYP26B1
# 13                                   hsa-miR-142-3p.2         MAP4K3
# 14                                     hsa-miR-144-3p         SAMD12
# 15                      hsa-miR-27a-3p/hsa-miR-27b-3p         NPEPPS
# 16                     hsa-miR-145-5p/hsa-miR-5195-3p          FSCN1
# 17                                   hsa-miR-101-3p.1          MAPK1
# 18                     hsa-miR-141-3p/hsa-miR-200a-3p         ZFAND5
# 19  hsa-miR-30a-5p/hsa-miR-30b-5p/hsa-miR-30c-5p/h...       PPARGC1B
# 20                                   hsa-miR-124-3p.1        PLEKHM3
# 21  hsa-miR-181a-5p/hsa-miR-181b-5p/hsa-miR-181c-5...          TNPO1
# 22                         hsa-miR-300/hsa-miR-381-3p           DVL2
# 23                     hsa-miR-133a-3p.2/hsa-miR-133b           GDI2
# 24                                     hsa-miR-129-5p        CAMK2N1
# 25                                   hsa-miR-140-3p.1          CELF2
# 26  hsa-let-7a-5p/hsa-let-7b-5p/hsa-let-7c-5p/hsa-...          RDH10
# 27  hsa-miR-302a-3p/hsa-miR-302b-3p/hsa-miR-302c-3...          SNTB2
# 28                                   hsa-miR-183-5p.2          TBX15
# 29                                    hsa-miR-323a-3p         MAP4K5
# 30                                      hsa-miR-31-5p          STK40
# 31                  hsa-miR-129-1-3p/hsa-miR-129-2-3p           DGKI
# 32               hsa-miR-1-3p/hsa-miR-206/hsa-miR-613          TNKS2
# 33                        hsa-miR-3167/hsa-miR-876-5p         HS3ST1
# 34                                   hsa-miR-183-5p.1         KCNK10
# 35                    hsa-miR-135a-5p/hsa-miR-135b-5p            SP3
# 36                    hsa-miR-124-3p.2/hsa-miR-506-3p         ZBTB20
# 37  hsa-miR-34a-5p/hsa-miR-34c-5p/hsa-miR-449a/hsa...          SCN2B
# 38                     hsa-miR-142-5p/hsa-miR-5590-3p        PLEKHA3
# 39                                        hsa-miR-802         DNAJB4
# 40                                        hsa-miR-421         CLDN11
# 41                        hsa-miR-103a-3p/hsa-miR-107         DICER1
# 42  hsa-miR-25-3p/hsa-miR-32-5p/hsa-miR-363-3p/hsa...          CPEB3
# 43                                     hsa-miR-582-5p          MKRN2
# 44       hsa-miR-29a-3p/hsa-miR-29b-3p/hsa-miR-29c-3p           PI15
# 45                        hsa-miR-495-3p/hsa-miR-5688        CYP26B1
# 46                                     hsa-miR-138-5p           GGCX
# 47                                     hsa-miR-299-5p           TLL1
# 48    hsa-miR-219a-5p/hsa-miR-4782-3p/hsa-miR-6766-3p           RORB
# 49                                        hsa-miR-137        GUCY1A2

# %%
#exporting the data as csv 
import os  
os.makedirs('/home/careen/Downloads/miRNA_multiscelorisis', exist_ok=True)  
df_set2.to_csv('/home/careen/Downloads/miRNA_multiscelorisis/miRNA-gene.csv')

# %%
# exporting the data as excel
import os  
os.makedirs('/home/careen/Downloads/miRNA_multiscelorisis', exist_ok=True) 
with pd.ExcelWriter('/home/careen/Downloads/miRNA_multiscelorisis/miRNA-gene.xlsx') as writer:  
    df_set2.to_excel(writer, sheet_name='Sheet_name_1')
